# %% [markdown]
# ## Programación Orientada a Objetos con Python

# %% [markdown]
# Realizar un pequeño proyecto para representar mediante clases y objetos juegos con un mazo de carta españolas, como la casita robada, la escoba de 15, el chinchon o el truco argentino. Recordar escribir en cada ejercicio los casos de prueba que correspondan.
#
# Conocimiento de base: Un mazo de cartas españolas trae 50 cartas. Estas estan clasificadas segun su _palo_, que puede ser Bastos, Espadas, Copas u Oros. Hay 12 cartas de cada tipo, numeradas correspondientemente. Es común llamar Sota a la carta con el número 10, Caballo a la carta con el número 11, Rey a la carta con el número 12 y As a la carta con el número. El mazo de cartas de españolas se completa con dos comodines.
#
# **Ejercicio 1**: Definir una clase Carta que contenga todos los atributos necesarios para describir las 40 cartas españolas necesarias para el Truco.

# %%
import random
class Carta:
    # Diccionario con los apodos de algunas cartas
    apodos = {
        1: "Ancho",
        10: "Sota",
        11: "Caballo",
        12: "Rey"
    }

    def __init__(self, numero, palo):
        self.numero = numero
        self.palo = palo
    def __str__(self):
        if self.numero in self.apodos:
            return f"{self.apodos[self.numero]} de {self.palo}"
        else:
            return f"{self.numero} de {self.palo}"

# %% [markdown]
# **Ejercicio 2**: Instanciar objetos que representen el as de espadas, el 3 de copas y el rey de bastos

# %%
ancho_de_espadas = Carta(1, "Espadas")
tres_de_copas = Carta(3, "Copas")
rey_de_bastos = Carta(12, "Bastos")

print(ancho_de_espadas.numero, ancho_de_espadas.palo)   # 1 Espadas
print(tres_de_copas.numero, tres_de_copas.palo)         # 3 Copas
print(rey_de_bastos.numero, rey_de_bastos.palo)         # 12 Bastos
# Out:
# 1 Espadas
# 3 Copas
# 12 Bastos

# %% [markdown]
# **Ejercicio 3**: Extender la definicion de Carta para definir un método que nos permita imprimir las cartas como lo haríamos naturalmente. Ejemplo: 5 de Basto.

# %%
class Mazo:
    def __init__(self):
        self.cartas = []
        palos = ["Bastos", "Espadas", "Copas", "Oros"]

        # En el Truco se usan 40 cartas (1 al 7 y 10 al 12)
        for palo in palos:
            for numero in [1, 2, 3, 4, 5, 6, 7, 10, 11, 12]:
                self.cartas.append(Carta(numero, palo))

    def cantidad(self):
        return len(self.cartas)

    def mezclar(self):
        random.shuffle(self.cartas)

# %%
ancho_de_espadas = Carta(1, "Espadas")
tres_de_copas = Carta(3, "Copas")
rey_de_bastos = Carta(12, "Bastos")

print(ancho_de_espadas)   # As de Espadas
print(tres_de_copas)      # 3 de Copas
print(rey_de_bastos)      # Rey de Bastos
# Out:
# Ancho de Espadas
# 3 de Copas
# Rey de Bastos

# %% [markdown]
# **Ejercicio 4**: Escribir un método que nos permita comparar cartas por igualdad

# %%
class Mazo:
    def __init__(self):
        self.cartas = []
        palos = ["Bastos", "Espadas", "Copas", "Oros"]

        # Cartas del Truco: 1 al 7 y 10, 11, 12
        for palo in palos:
            for numero in [1, 2, 3, 4, 5, 6, 7, 10, 11, 12]:
                 self.cartas.append(Carta(numero, palo))

    def cantidad(self):
        return len(self.cartas)

    def mezclar(self):
        random.shuffle(self.cartas)

    def sacar_carta(self):
      if self.cantidad > o:
        return self.cartas.pop()

    def sacar_carta(self):
      if self.cartas:
        carta_sacada = self.cartas.pop()
        return str(carta_sacada)


# Caso de prueba
mazo = Mazo()
print(mazo.cantidad())

mazo.mezclar()
for carta in mazo.cartas:
  print(carta)

carta_sacada = mazo.sacar_carta()
print(f"Carta sacada: {carta_sacada}")
print(f"Cartas restantes: {mazo.cantidad()}")
# Out:
# 40
# Rey de Bastos
# 4 de Copas
# 5 de Bastos
# Rey de Copas
# Caballo de Bastos
# 4 de Oros
# 2 de Oros
# 7 de Bastos
# 2 de Espadas
# 4 de Bastos
# 7 de Oros
# 2 de Copas
# 7 de Copas
# Caballo de Copas
# 7 de Espadas
# Rey de Oros
# 6 de Bastos
# 2 de Bastos
# Caballo de Oros
# Sota de Bastos
# Ancho de Espadas
# 3 de Oros
# Sota de Oros
# 6 de Copas
# 3 de Bastos
# 5 de Espadas
# Rey de Espadas
# Caballo de Espadas
# Ancho de Oros
# 5 de Copas
# Sota de Espadas
# 4 de Espadas
# 6 de Espadas
# Ancho de Bastos
# Ancho de Copas
# 3 de Copas
# 3 de Espadas
# Sota de Copas
# 6 de Oros
# 5 de Oros
# Carta sacada: 5 de Oros
# Cartas restantes: 39

# %%
carta_sacada = mazo.sacar_carta()
print(f"Carta sacada: {carta_sacada}")
print(f"Cartas restantes: {mazo.cantidad()}")
# Out:
# Carta sacada: 6 de Oros
# Cartas restantes: 38
